# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read files by pandas

df1 = pd.read_csv(r"G:\AI\project2\ecommerce_customer_data_custom_ratios.csv")

df2 = pd.read_csv(r"G:\AI\project2\ecommerce_customer_data_large.csv")

# %%
#display table 1
df1
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
#display table 2
df2
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             44605  2023-05-03 21:30:02             Home            177
# 1             44605  2021-05-16 13:57:44      Electronics            174
# 2             44605  2020-07-13 06:16:57            Books            413
# 3             44605  2023-01-17 13:14:36      Electronics            396
# 4             44605  2021-05-01 11:29:27            Books            259
# ...             ...                  ...              ...            ...
# 249995        33807  2023-01-24 12:32:18             Home            436
# 249996        20455  2021-06-04 05:45:25      Electronics            233
# 249997        28055  2022-11-10 17:11:57      Electronics            441
# 249998        15023  2021-06-27 14:42:12      Electronics             44
# 249999         4148  2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
#take information from tables
df1.info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB
# ...

# %%
# make describe to table 1
df1.describe()
# Out:
#         Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.00000  250000.000000  250000.000000          250000.000000
# mean    25004.03624     254.659512       2.998896            2725.370732
# std     14428.27959     141.568577       1.414694            1442.933565
# min         1.00000      10.000000       1.000000             100.000000
# 25%     12497.75000     132.000000       2.000000            1477.000000
# 50%     25018.00000     255.000000       3.000000            2724.000000
# 75%     37506.00000     377.000000       4.000000            3974.000000
# max     50000.00000     500.000000       5.000000            5350.000000
#
#         Customer Age        Returns            Age          Churn
# count  250000.000000  202404.000000  250000.000000  250000.000000
# mean       43.940528       0.497861      43.940528       0.199496
# std        15.350246       0.499997      15.350246       0.399622
# ...

# %%
# make describe to table 2

df2.describe()
# Out:
#          Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.000000  250000.000000  250000.000000          250000.000000
# mean    25017.632092     254.742724       3.004936            2725.385196
# std     14412.515718     141.738104       1.414737            1442.576095
# min         1.000000      10.000000       1.000000             100.000000
# 25%     12590.000000     132.000000       2.000000            1476.000000
# 50%     25011.000000     255.000000       3.000000            2725.000000
# 75%     37441.250000     377.000000       4.000000            3975.000000
# max     50000.000000     500.000000       5.000000            5350.000000
#
#         Customer Age        Returns            Age         Churn
# count  250000.000000  202618.000000  250000.000000  250000.00000
# mean       43.798276       0.500824      43.798276       0.20052
# std        15.364915       0.500001      15.364915       0.40039
# ...

# %%
#display first 10 rows
df1.head(10)
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
# 5        13593  2023-03-07 14:17:42             Home            250         4
# 6        13593  2023-04-15 03:02:33      Electronics             73         1
# 7        13593  2021-03-27 21:23:28            Books            337         2
# 8        13593  2020-05-05 20:14:00         Clothing            182         2
# 9        28805  2023-09-13 04:24:00      Electronics            394         2
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
#display random 10 rows
df1.sample(10)
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 19428         45706  2023-04-13 12:44:47            Books            271
# 23091         15924  2022-11-29 17:16:54         Clothing            258
# 143176        27611  2022-05-10 02:59:23            Books            410
# 247524        21495  2020-06-14 08:19:02         Clothing            138
# 83155          2610  2021-09-16 15:52:00      Electronics            249
# 43098         45063  2022-04-14 19:22:30         Clothing            243
# 209326        26597  2022-07-09 13:44:39         Clothing            332
# 212139         9384  2021-02-14 15:38:38         Clothing             62
# 134359        37062  2021-03-01 16:40:48         Clothing            447
# 179006        29074  2023-04-19 09:45:04            Books            356
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 19428          1                    666    Credit Card            65      0.0
# ...

# %%
#display last 10 rows

df2.tail(10)
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 249990          150  2023-08-23 01:47:29             Home            196
# 249991        16247  2020-06-24 17:29:27      Electronics            368
# 249992        48538  2020-12-13 02:09:15      Electronics            239
# 249993        39806  2021-12-07 05:42:38      Electronics            215
# 249994        39806  2021-08-01 04:43:12      Electronics            225
# 249995        33807  2023-01-24 12:32:18             Home            436
# 249996        20455  2021-06-04 05:45:25      Electronics            233
# 249997        28055  2022-11-10 17:11:57      Electronics            441
# 249998        15023  2021-06-27 14:42:12      Electronics             44
# 249999         4148  2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 249990         3                   1743         PayPal            68      0.0
# ...

# %%
#dispaly sum of nan is table1
df1.isna().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47596
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %%
#dispaly sum of nan is table2
df2.isna().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47382
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %%
#reblace nan with 0
df1['Returns'] = df1['Returns'].fillna(0)
df1.sample(5)
# Out:
#         Customer ID       Purchase Date Product Category  Product Price  \
# 246095        35346 2020-01-04 19:22:03            Books            265
# 94661         35037 2020-04-24 23:01:32      Electronics             89
# 3126           5980 2021-03-07 17:23:25         Clothing            138
# 240205        41727 2023-02-09 07:21:19         Clothing             17
# 173569        20193 2021-12-25 03:56:02      Electronics            137
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 246095         5                   1980         Crypto            24      1.0
# 94661          1                   4218    Credit Card            57      1.0
# 3126           1                   5045           Cash            61      0.0
# 240205         3                   2441    Credit Card            25      0.0
# 173569         1                   2548           Cash            68      0.0
#
#               Customer Name  Age  Gender  Churn
# ...

# %%
#reblace nan with 0
df2['Returns'] = df2['Returns'].fillna(0)
df2.sample(5)
# Out:
#         Customer ID       Purchase Date Product Category  Product Price  \
# 174154        33619 2023-05-21 21:08:10         Clothing             18
# 199608         2641 2021-01-11 09:48:10      Electronics            286
# 136483         5978 2021-12-12 19:27:59            Books            236
# 18513          7241 2020-06-16 17:08:38      Electronics            163
# 53361          6189 2021-04-16 20:34:11            Books            321
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 174154         3                   4478           Cash            47      1.0
# 199608         5                   5058    Credit Card            43      0.0
# 136483         3                    346         PayPal            46      0.0
# 18513          3                   2747           Cash            41      1.0
# 53361          1                   2865    Credit Card            47      1.0
#
#            Customer Name  Age  Gender  Churn
# ...

# %%
df1['Purchase Date'] = pd.to_datetime(df1['Purchase Date'])

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  datetime64[ns]
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                250000 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(4)
# ...

# %%
df2['Purchase Date'] = pd.to_datetime(df2['Purchase Date'])

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  datetime64[ns]
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                250000 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(4)
# ...

# %%
#dim of table 1
df1.shape
# Out:
# (250000, 13)

# %%
#dim of table 2

df2.shape
# Out:
# (250000, 13)

# %%
#duplicated in table 1
df1.duplicated().sum()
# Out:
# 0

# %%
#duplicated in table 1

df2.duplicated().sum()
# Out:
# 0

# %%
#number of values in column of Customer Name
df1['Customer Name'].value_counts()
# Out:
# Customer Name
# Michael Smith        107
# John Smith           103
# Jennifer Smith       102
# Michael Johnson       98
# Lisa Smith            97
#                     ...
# Haley Harris           1
# Joseph Joyce           1
# Jonathan Price MD      1
# Sarah Melton           1
# Justin Lawson          1
# Name: count, Length: 39920, dtype: int64

# %%
#download table1
df1.to_csv(r'G:\AI\project2\ecommerce_customer_data_custom_ratios-NEW.csv')

# %%
#download table2

df2.to_csv(r"G:\AI\project2\ecommerce_customer_data_large-NEW.csv")
